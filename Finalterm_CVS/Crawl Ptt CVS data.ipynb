# %%
from PTT_Crawler import CVS_PttCrawler

# %%
crawler = CVS_PttCrawler()
crawler.crawl(board="CVS", start=2289, end=2336)
# Out:
# 已經完成 CVS 頁面第 2289 頁的爬取
# 爬取完成~ cvs_data/CVS2289.json 輸出成功！
# 格式不符
# 格式不符
# 已經完成 CVS 頁面第 2290 頁的爬取
# 爬取完成~ cvs_data/CVS2290.json 輸出成功！
# 已經完成 CVS 頁面第 2291 頁的爬取
# 爬取完成~ cvs_data/CVS2291.json 輸出成功！
# 已經完成 CVS 頁面第 2292 頁的爬取
# 爬取完成~ cvs_data/CVS2292.json 輸出成功！
# 格式不符
# 已經完成 CVS 頁面第 2293 頁的爬取
# 爬取完成~ cvs_data/CVS2293.json 輸出成功！
# 格式不符
# 格式不符
# 格式不符
# 已經完成 CVS 頁面第 2294 頁的爬取
# 爬取完成~ cvs_data/CVS2294.json 輸出成功！
# 已經完成 CVS 頁面第 2295 頁的爬取
# 爬取完成~ cvs_data/CVS2295.json 輸出成功！
# list index out of range
# 在分析 https://www.ptt.cc/bbs/CVS/M.1584502999.A.C21.html 時出現錯誤
# 已經完成 CVS 頁面第 2296 頁的爬取
# 爬取完成~ cvs_data/CVS2296.json 輸出成功！
# 格式不符
# 已經完成 CVS 頁面第 2297 頁的爬取
# 爬取完成~ cvs_data/CVS2297.json 輸出成功！
# list index out of range
# 在分析 https://www.ptt.cc/bbs/CVS/M.1584943057.A.D43.html 時出現錯誤
# 已經完成 CVS 頁面第 2298 頁的爬取
# 爬取完成~ cvs_data/CVS2298.json 輸出成功！
# 已經完成 CVS 頁面第 2299 頁的爬取
# 爬取完成~ cvs_data/CVS2299.json 輸出成功！
# 格式不符
# 已經完成 CVS 頁面第 2300 頁的爬取
# 爬取完成~ cvs_data/CVS2300.json 輸出成功！
# 已經完成 CVS 頁面第 2301 頁的爬取
# ...
